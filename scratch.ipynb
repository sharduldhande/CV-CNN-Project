# %%
import mat73

# %%
file_path = 'Data/train/digitStruct.mat'
print(file_path)
data = mat73.loadmat(file_path)
print("Keys :", list(data.keys()))

# %%
print(type(data))
print(len(data))

# %%
print(type(data['digitStruct']))

# %%
print("Keys :", list(data['digitStruct'].keys()))
# Out:
# Keys : ['bbox', 'name']

# %%
# print(data['digitStruct']['bbox'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 print(data['digitStruct']['bbox'])
#
# File /opt/miniconda3/envs/CS6476/lib/python3.9/site-packages/numpy/core/arrayprint.py:1508, in _array_repr_implementation(arr, max_line_width, precision, suppress_small, array2string)
#    1506     lst = repr(arr.item())
#    1507 elif arr.size > 0 or arr.shape == (0,):
# -> 1508     lst = array2string(arr, max_line_width, precision, suppress_small,
#    1509                        ', ', prefix, suffix=suffix)
#    1510 else:  # show zero-length shape unless it is (0,)
#    1511     lst = "[], shape=%s" % (repr(arr.shape),)
#
# ...

# %%
print(type(data['digitStruct']['bbox']))
# Out:
# <class 'list'>

# %%
print(data['digitStruct']['bbox'][1])
# Out:
# {'height': [array(32.), array(32.)], 'label': [array(2.), array(3.)], 'left': [array(77.), array(98.)], 'top': [array(29.), array(25.)], 'width': [array(23.), array(26.)]}

# %%
imageNum = 4
print(''.join([str(int(array1)) for array1 in data['digitStruct']['bbox'][imageNum-1]['label']]))
# Out:
# 93
