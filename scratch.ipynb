# %%
import mat73

# %%
file_path = 'Data/train/digitStruct.mat'
print(file_path)
data = mat73.loadmat(file_path)
print("Keys :", list(data.keys()))
# Out:
# Data/train/digitStruct.mat
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 file_path = 'Data/train/digitStruct.mat'
#       2 print(file_path)
# ----> 3 data = mat73.loadmat(file_path)
#       4 print("Keys :", list(data.keys()))
#
# File /opt/miniconda3/envs/CS6476/lib/python3.9/site-packages/mat73/core.py:347, in loadmat(file, use_attrdict, only_include, verbose)
#     345 try:
#     346     with h5py.File(file, 'r') as hdf5:
# --> 347         dictionary = decoder.mat2dict(hdf5)
#     348     return dictionary
#     349 except FileNotFoundError:
#
# File /opt/miniconda3/envs/CS6476/lib/python3.9/site-packages/mat73/core.py:93, in HDF5Decoder.mat2dict(self, hdf5)
#      91     if not self.is_included(hdf5[var]):
#      92         continue
# ---> 93     d[var] = self.unpack_mat(hdf5[var])
#      95 if self.only_include is not None:
# ...

# %%
print(type(data))
print(len(data))
# Out:
# <class 'dict'>
# 1

# %%
print(type(data['digitStruct']))
# Out:
# <class 'dict'>

# %%
print("Keys :", list(data['digitStruct'].keys()))
# Out:
# Keys : ['bbox', 'name']

# %%
imageNum = 12
print(data['digitStruct']['bbox'][imageNum-1])
print(data['digitStruct']['name'][imageNum-1])
imageNum = 21
print(data['digitStruct']['bbox'][imageNum-1])
print(data['digitStruct']['name'][imageNum-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 imageNum = 12
# ----> 2 print(data['digitStruct']['bbox'][imageNum-1])
#       3 print(data['digitStruct']['name'][imageNum-1])
#       4 imageNum = 21
#
# NameError: name 'data' is not defined

# %%
print(''.join([str(int(array1)) for array1 in data['digitStruct']['bbox'][imageNum-1]['label']]))
