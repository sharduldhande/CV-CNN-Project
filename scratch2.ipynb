# %%
import pickle

# %%
bboxes_path = 'Data/train/bboxes.pkl'
names_path = 'Data/train/names.pkl'

with open(bboxes_path, 'rb') as file:
    original_bboxes = pickle.load(file)
with open(names_path, 'rb') as file1:
    original_names = pickle.load(file1)

# %%
print(type(original_bboxes))
print(len(original_bboxes))
print(type(original_names))
print(len(original_names))
# Out:
# <class 'list'>
# 33402
# <class 'list'>
# 33402

# %%
print(original_bboxes[11])
print(original_names[11])
print(original_bboxes[20])
print(original_names[20])
# Out:
# [{'height': 55.0, 'width': 23.0, 'top': 16.0, 'left': 67.0, 'label': 6}, {'height': 55.0, 'width': 20.0, 'top': 17.0, 'left': 90.0, 'label': 3}]
# 12.png
# [{'height': 85.0, 'width': 52.0, 'top': 6.0, 'left': 72.0, 'label': 2}]
# 21.png
